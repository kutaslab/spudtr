# %%
from spudtr import epf1, DATA_DIR, P3_F, P5_F, WR_F
import spudtr.fake_epochs_data as fake_data

from spudtr.epf1 import EPOCH_ID, TIME

import numpy as np
import pandas as pd

# %%
_f, _key = DATA_DIR / "gh_sub000p3.epochs.h5", "p3"
epochs_df = epf1._hdf_read_epochs(DATA_DIR / _f, _key)
eeg_streams = ["MiPf", "MiCe", "MiPa", "MiOc"]
start, stop = -50, 300

# %%
#%timeit 
epochs_df1 = epf1.center_eeg(epochs_df, eeg_streams, start, stop, time="time_ms")
display(epochs_df1)
# Out:
# center_eeg is correct
#         epoch_id  time_ms  event_code  eeg_artifact    participant       MiPf  \
# 0              0     -500           0             0  demonstration -10.396553
# 1              0     -496           0             0  demonstration  -6.896553
# 2              0     -492           0             0  demonstration  -8.396553
# 3              0     -488           0             0  demonstration  -9.896553
# 4              0     -484           0             0  demonstration  -9.396553
# ...          ...      ...         ...           ...            ...        ...
# 296995       791      980           0             0  demonstration   2.051724
# 296996       791      984           0             0  demonstration  -4.448276
# 296997       791      988           0             0  demonstration   5.051724
# 296998       791      992           0             0  demonstration  -0.448276
# 296999       791      996           0             0  demonstration   3.051724
#
#              MiCe       MiPa       MiOc        A2    stim accuracy acc_type  \
# 0        3.362249   3.184807  -0.236376  7.382812  target  correct      hit
# 1        6.393499   6.278557   3.646437  8.367188  target  correct      hit
# 2        3.862249   4.622307   0.005812  3.937500  target  correct      hit
# 3        2.846624   2.934807   0.005812  1.722656  target  correct      hit
# 4        4.112249   0.559807  -4.123095  0.984375  target  correct      hit
# ...           ...        ...        ...       ...     ...      ...      ...
# 296995  11.448063   2.561296  -9.401198 -2.460938     all      all      all
# 296996   9.682438   0.412859 -10.372878 -6.398438     all      all      all
# 296997  21.323063  12.342546   3.234544  6.890625     all      all      all
# 296998  19.041813  10.905046   1.289231  4.429688     all      all      all
# 296999  20.307438  11.389421   1.047044  6.398438     all      all      all
#
#        exp
# 0       p3
# 1       p3
# 2       p3
# 3       p3
# 4       p3
# ...     ..
# 296995  p3
# 296996  p3
# 296997  p3
# 296998  p3
# 296999  p3
#
# [297000 rows x 14 columns]

# %%
from spudtr import epf, DATA_DIR, P3_F, P5_F, WR_F
import spudtr.fake_epochs_data as fake_data

from spudtr.epf import EPOCH_ID, TIME

import numpy as np
import pandas as pd

# %%
_f, _key = DATA_DIR / "gh_sub000p3.epochs.h5", "p3"
epochs_df_new = epf._hdf_read_epochs(DATA_DIR / _f, _key)
eeg_streams = ["MiPf", "MiCe", "MiPa", "MiOc"]
start, stop = -50, 300

# %%
#%%timeit

epf.center_eeg(epochs_df_new, eeg_streams, start, stop, time="time_ms")

# %%
x = epochs_df1[eeg_streams].values
y = epochs_df_new[eeg_streams].values

# %%
np.allclose(x, y, atol=1e-04)
# Out:
# True
